# %%
# %reset -f
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import crc
import matplotlib.pyplot as plt
import time

# %%
scenario = 'NS'
n        = 0
mode     = '2,2'

# %%
# %autoreload
# t_i = time.time()
# crc.generate_waveforms_SEOBNRv5_to_save(scenario, n, mode)
# print(f"\n{time.time() - t_i:.3f} seconds")

# %%
# # get waveforms
# %autoreload
# waveforms = crc.generate_waveforms_SEOBNRv5_NS(n, mode)
# waveforms = crc.add_A_phi(waveforms)

# %%
# %autoreload
# crc.load_stats(scenario, n, mode, 'h', 'SEOBNRv5HM')

# %%
# %autoreload
t_i = time.time()
waveforms = crc.add_A_phi(crc.load_waveforms(scenario, n, mode))
print(f"\n{time.time() - t_i:.3f} seconds")
# Out:
# 0.407 seconds

# %%
# %autoreload
crc.p1peline(crc.reformat(waveforms)[1], scenario, n, mode, 'A', 1e-12, plotting = True, saving = False)
# crc.p1peline(crc.reformat(waveforms)[2], scenario, n, mode, 'phi', 1e-8, plotting = True, saving = False)
# Out:
# P1PELINE: NS | 0 | 2,2 | 1e-12 | A
# RB: constructing reduced basis
# ...
# tolerance met: 42/1000 vectors in reduced basis
# orth: 10^(-16.256)
# norm: 10^(-15.654)
# ...
# RB: reduced basis complete
# RB: time elapsed: 10.172
# RB: plotting reduced basis
# EI: constructing B matrix
# B matrix complete
# EI: B matrix complete
# EI: time elapsed: 0.049

# %%
# %autoreload
t_i = time.time()
crc.p3peline_noANN(scenario, n, mode, plotting = True)
print(f"\n{time.time() - t_i:.3f} seconds")
# Out:
# 2024-04-05 21:44:46.143024: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-05 21:44:47.318794: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-05 21:44:47.318902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-05 21:44:47.395560: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-05 21:44:47.456827: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-05 21:44:59.073412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# phi ) ind: 145.000| mismatch: 10^(-13.624)
# full) ind: 145.000| mismatch: 10^(-10.358)
# 82.641 seconds

# %%
# %autoreload
# t_i = time.time()
# # A = crc.reformat(waveforms)[1]
# crc.p2peline_A(waveforms, scenario, n, mode, saving = True, plotting = True)
# # phi = crc.reformat(waveforms)[2]
# crc.p2peline_phi(waveforms, scenario, n, mode, saving = True, plotting = True)
# print(f"\n{time.time() - t_i:.3f} seconds")

# %%
# %autoreload
# t_i = time.time()
# crc.p3peline(scenario, n, mode, plotting = True, mismatches = True)
# print(f"\n{time.time() - t_i:.3f} seconds")
